# %% [markdown]
# # 00_setup
#
# Ce notebook explique comment configurer l'environnement, vérifier la présence d'un GPU et lancer les notebooks d'apprentissage.
#
# Suivez les étapes : créer l'environnement, installer les dépendances (via environment.yml) et démarrer Jupyter.

# %%
# Vérifier la version de Python et la disponibilité de PyTorch
import sys
print('Python:', sys.version)
import torch
print('PyTorch:', torch.__version__)
print('CUDA disponible :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Device name :', torch.cuda.get_device_name(0))

# %% [markdown]
# Si tout est OK, passe au notebook `01_toy_gan.ipynb` qui contient un tutoriel complet pas-à-pas (avec code en français).
